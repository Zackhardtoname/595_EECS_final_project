# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/drive')

import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "595_EECS_final_project/commonsenseqa/bert"
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))

import sys
sys.path.append(GOOGLE_DRIVE_PATH)
# Out:
# Mounted at /content/drive
# ['bert_model.ckpt.data-00000-of-00001', 'bert_model.ckpt.meta', 'modeling_test.py', 'optimization_test.py', '__init__.py', 'CONTRIBUTING.md', 'modeling.py', 'run_classifier.py', 'README.md', 'optimization.py', 'run_pretraining.py', 'multilingual.md', 'tokenization.py', 'create_pretraining_data.py', 'extract_features.py', 'run_commonsense_qa.py', 'run_squad.py', 'LICENSE', 'tokenization_test.py', 'sample_text.txt', 'train_rand_split.jsonl', 'requirements.txt', 'checkpoint', 'model.ckpt-0.index', '__pycache__', 'output', '.ipynb_checkpoints', 'bert_config.json', 'bert_model.ckpt.index', 'vocab.txt', 'test_rand_split_no_answers.jsonl', 'dev_rand_split.jsonl', 'bert.ipynb']

# %%
tpu= 'grpc://' + os.environ['COLAB_TPU_ADDR']
tpu
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-50c289bc49e4> in <module>()
# ----> 1 tpu= 'grpc://' + os.environ['COLAB_TPU_ADDR']
#       2 tpu
#
# /usr/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'COLAB_TPU_ADDR'

# %%
# %cd ./drive/My Drive/595_EECS_final_project/commonsenseqa/bert/
# !pwd
# Out:
# [Errno 2] No such file or directory: './drive/My Drive/595_EECS_final_project/commonsenseqa/bert/'
# /content/drive/My Drive/595_EECS_final_project/commonsenseqa/bert
# /content/drive/My Drive/595_EECS_final_project/commonsenseqa/bert

# %%
# --use_tpu=true \
# --tpu_name=grpc://10.103.217.114:8470 \

# !python "run_commonsense_qa.py" --split=rand \
--do_train=true \
--do_eval=true \
--data_dir=./ \
--vocab_file=./vocab.txt \
--bert_config_file=./bert_config.json \
--init_checkpoint=./bert_model.ckpt \
--max_seq_length=32 \
--train_batch_size=4 \
--learning_rate=2e-5 \
--num_train_epochs=3.0 \
--output_dir=./output/
# Out:
# Streaming output truncated to the last 5000 lines.
# I1105 23:51:35.512142 140061608769408 tpu_estimator.py:2307] global_step/sec: 1.583
# INFO:tensorflow:examples/sec: 6.332
# I1105 23:51:35.512567 140061608769408 tpu_estimator.py:2308] examples/sec: 6.332
# INFO:tensorflow:global_step/sec: 1.57439
# I1105 23:51:36.147323 140061608769408 tpu_estimator.py:2307] global_step/sec: 1.57439
# INFO:tensorflow:examples/sec: 6.29758
# I1105 23:51:36.147690 140061608769408 tpu_estimator.py:2308] examples/sec: 6.29758
# INFO:tensorflow:global_step/sec: 1.57622
# I1105 23:51:36.781732 140061608769408 tpu_estimator.py:2307] global_step/sec: 1.57622
# INFO:tensorflow:examples/sec: 6.30487
# I1105 23:51:36.782099 140061608769408 tpu_estimator.py:2308] examples/sec: 6.30487
# INFO:tensorflow:global_step/sec: 1.57582
# I1105 23:51:37.416356 140061608769408 tpu_estimator.py:2307] global_step/sec: 1.57582
# INFO:tensorflow:examples/sec: 6.30327
# ...

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

import psutil
import humanize
import os
import GPUtil as GPU

GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
    process = psutil.Process(os.getpid())
    print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " |     Proc size: " + humanize.naturalsize(process.memory_info().rss))
    print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total     {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7411 sha256=15522ad8d69f47bd04839730962e168b8b8e25e47b4f2f9ad01003c9f41059b6
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.6 GB  |     Proc size: 156.1 MB
# GPU RAM Free: 15079MB | Used: 0MB | Util   0% | Total     15079MB
